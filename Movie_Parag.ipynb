# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1) Import Data from csv files

# %%
credits = pd.read_csv('credits.csv')

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
keywords = pd.read_csv('keywords.csv')

# %%
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
links = pd.read_csv('links.csv')

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
md = pd.read_csv('movies_metadata.csv')

# %%
md.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
rating = pd.read_csv('ratings.csv')

# %%
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %% [markdown]
# Analyzing the Dataset

# %%
from tabulate import tabulate

# %%
table = [['DATASET','Rows and Column'], 
         ['credits',credits.shape],['keywords',keywords.shape],['links',links.shape],['movies medata',md.shape],['rating',rating.shape]]

# %%
print(tabulate(table, headers='firstrow',tablefmt='fancy_grid'))
# Out:
# ╒═══════════════╤═══════════════════╕
# │ DATASET       │ Rows and Column   │
# ╞═══════════════╪═══════════════════╡
# │ credits       │ (45476, 3)        │
# ├───────────────┼───────────────────┤
# │ keywords      │ (46419, 2)        │
# ├───────────────┼───────────────────┤
# │ links         │ (45843, 3)        │
# ├───────────────┼───────────────────┤
# │ movies medata │ (45466, 24)       │
# ├───────────────┼───────────────────┤
# │ rating        │ (26024289, 4)     │
# ╘═══════════════╧═══════════════════╛

# %%
print ("Credits Dataset with Data Type")
credits.info()
# Out:
# Credits Dataset with Data Type
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
print("links Dataset with Data Type")
links.info()
# Out:
# links Dataset with Data Type
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45843 entries, 0 to 45842
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  45843 non-null  int64
#  1   imdbId   45843 non-null  int64
#  2   tmdbId   45624 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.0 MB

# %%
print("movies metadata Dataset with Data Type")
md.info()
# Out:
# movies metadata Dataset with Data Type
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
# ...

# %%
print("Rating Dataset with Data Type")
rating.info()
# Out:
# Rating Dataset with Data Type
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
print("Keyword Dataset with Data Type")
rating.info()
# Out:
# Keyword Dataset with Data Type
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %% [markdown]
# DATA CLEANUP

# %% [markdown]
#      a) MOVIE METADATA (md file)

# %%
md.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
md.loc[0]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                            30000000
# genres                   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                              http://toystory.disney.com/toy-story
# id                                                                     862
# imdb_id                                                          tt0114709
# original_language                                                       en
# original_title                                                   Toy Story
# overview                 Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.946943
# poster_path                               /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# ...

# %% [markdown]
# We need to work on cleaning the data of belongs_to_collection and genres

# %%
# Drop unused column 

md = md.drop(['adult'], axis=1)
md = md.drop(['tagline'],axis=1)

### Preview Data 
md.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# ...

# %% [markdown]
# PRE-PROCESSING

# %% [markdown]
# a) Check Missing Values

# %%
print("Missing Value of Movie Dataset\n")
print( md.isna().sum())
print("\nMissing Value of Credits Dataset\n")
print (links.isna().sum())
print("\nMissing Value of Keywords Dataset\n")
print( keywords.isna().sum())
print("\nMissing Value of links Dataset\n")
print( links.isna().sum())
print("\nMissing Value of Rating Dataset\n")
print( rating.isna().sum())
# Out:
# Missing Value of Movie Dataset
#
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64
#
# Missing Value of Credits Dataset
#
# movieId      0
# imdbId       0
# tmdbId     219
# dtype: int64
#
# Missing Value of Keywords Dataset
#
# id          0
# keywords    0
# dtype: int64
#
# ...

# %% [markdown]
# MODEL 1 : Simple Recommodation

# %% [markdown]
# As a first step, let's calculate the value of C, the mean rating across all movies

# %%
## Calculate the mean of Vote Average 

C = md['vote_average'].mean()
print(C)
# Out:
# 5.618207215133889

# %% [markdown]
#  The average rating of a movie on IMDB is around 5.6 on a scale of 10.

# %% [markdown]
# We will use 90th percentile as our cutoff. In other words, for a movie to feature in the charts, it must have more votes than at least 90% of the movies in the list.

# %%
# Calculate the minimum number of votes required to be in the chart, m
m = md['vote_count'].quantile(0.90)
print(m)
# Out:
# 160.0

# %%
## Filter out qualified movie for the set 

q_movies = md.copy().loc[md['vote_count'] >= m ]
q_movies.shape
# Out:
# (4555, 22)

# %% [markdown]
# It is clear that there are around 10% movies with vote count more than 160.Now, we need to calculate our metric for each qualified movie. To do this, we will define a function, weighted_rating() and define a new feature score, of which we'll calculate the value by applying this function to our DataFrame of qualified movies:

# %%
def weighted_rating(x, m=m, C=C) : 
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Define a new feature 'score' and calculate its value with `weighted_rating()`
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %% [markdown]
# Finally, let's sort the DataFrame based on the score feature and output the title, vote count, vote average and weighted rating or score of the top 20 movies.

# %%
#Sort movies based on score calculated above
q_movies = q_movies.sort_values('score', ascending=False)

#Print the top 15 movies
q_movies[['title', 'vote_count', 'vote_average', 'score']].head(15)
# Out:
#                                  title  vote_count  vote_average     score
# 314           The Shawshank Redemption      8358.0           8.5  8.445869
# 834                      The Godfather      6024.0           8.5  8.425439
# 10309      Dilwale Dulhania Le Jayenge       661.0           9.1  8.421453
# 12481                  The Dark Knight     12269.0           8.3  8.265477
# 2843                        Fight Club      9678.0           8.3  8.256385
# 292                       Pulp Fiction      8670.0           8.3  8.251406
# 522                   Schindler's List      4436.0           8.3  8.206639
# 23673                         Whiplash      4376.0           8.3  8.205404
# 5481                     Spirited Away      3968.0           8.3  8.196055
# 2211                 Life Is Beautiful      3643.0           8.3  8.187171
# 1178            The Godfather: Part II      3418.0           8.3  8.180076
# ...

# %% [markdown]
# BREAK THE JSON FILES

# %%
md.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# ...

# %%
md.sort_values(by=['id'], ascending=True)
# Out:
#        adult belongs_to_collection   budget  \
# 2429   False                   NaN  1350000
# 13609  False                   NaN        0
# 4435   False                   NaN        0
# 17451  False                   NaN        0
# 36946  False                   NaN        0
# ...      ...                   ...      ...
# 25652  False                   NaN        0
# 3767   False                   NaN        0
# 12549  False                   NaN        0
# 25079  False                   NaN        0
# 13106  False                   NaN        0
#
#                                            genres  \
# 2429                              [Comedy, Crime]
# 13609                             [Comedy, Drama]
# 4435                    [Comedy, Science Fiction]
# 17451                                [Drama, War]
# 36946                                     [Drama]
# ...                                           ...
# 25652                                    [Comedy]
# ...

# %%
from ast import literal_eval

# %%
md['genres'] = md['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
md.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# ...

# %%
md['year'] = pd.to_datetime(md['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
md.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# ...

# %%
### Qulified - when vote count is greater than min no of votes and not null AND Vote Average is not null 
qualified = md[(md['vote_count'] >= m) & (md['vote_count'].notnull()) & (md['vote_average'].notnull())][['id','title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres', 'belongs_to_collection','homepage','imdb_id','original_title', 'overview', 'poster_path', 'status','video','original_language']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')
qualified.shape
# Out:
# (4555, 16)

# %%
qualified
# Out:
#            id                        title  year  vote_count  vote_average  \
# 0         862                    Toy Story  1995        5415             7
# 1        8844                      Jumanji  1995        2413             6
# 4       11862  Father of the Bride Part II  1995         173             5
# 5         949                         Heat  1995        1886             7
# 8        9091                 Sudden Death  1995         174             5
# ...       ...                          ...   ...         ...           ...
# 45177  375798                      Brice 3  2016         160             4
# 45204  417870                   Girls Trip  2017         393             7
# 45258  417320                Descendants 2  2017         171             7
# 45265  265189                Force Majeure  2014         255             6
# 45343  248705   The Visitors: Bastille Day  2016         167             4
#
# ...

# %% [markdown]
# Therefore, to qualify to be considered for the chart, a movie has to have at least 434 votes on TMDB. We also see that the average rating for a movie on TMDB is 5.6 on a scale of 10. 4555 Movies qualify to be on our chart.

# %%
qualified['Weighted Rating'] = qualified.apply(weighted_rating, axis=1)

# %%
qualified = qualified.sort_values('id', ascending=True)

# %%
qualified.head()
# Out:
#       id            title  year  vote_count  vote_average popularity  \
# 17     5       Four Rooms  1995         539             6   9.026586
# 256   11        Star Wars  1977        6778             8  42.149697
# 6232  12     Finding Nemo  2003        6292             7  25.497794
# 351   13     Forrest Gump  1994        8147             8  48.307194
# 2742  14  American Beauty  1999        3438             7  20.726578
#
#                                     genres  \
# 17                         [Crime, Comedy]
# 256   [Adventure, Action, Science Fiction]
# 6232                   [Animation, Family]
# 351               [Comedy, Drama, Romance]
# 2742                               [Drama]
#
#                                   belongs_to_collection  \
# 17                                                  NaN
# 256   {'id': 10, 'name': 'Star Wars Collection', 'po...
# 6232  {'id': 137697, 'name': 'Finding Nemo Collectio...
# 351                                                 NaN
# ...

# %% [markdown]
# The top movie according to our metrics is Bollywood's Dilwale Dulhania Le Jayenge

# %%
# calculate the average rating by movieID

rating_average = rating.groupby(['movieId']).mean()[['rating']]

# %%
rating_average
# Out:
#            rating
# movieId
# 1        3.888157
# 2        3.236953
# 3        3.175550
# 4        2.875713
# 5        3.079565
# ...           ...
# 176267   4.000000
# 176269   3.500000
# 176271   5.000000
# 176273   1.000000
# 176275   3.000000
#
# [45115 rows x 1 columns]

# %% [markdown]
# MERGE DATASET INTO ONE

# %%
## Merging  Credits with Movies Qualified Data (Taking credits with id and merge with Movie id ) = MERGE1
qualified['id'] = qualified.id.astype(int)

# %%
merge1 = qualified.merge(credits,on='id')

# %%
merge1.head()
# Out:
#        id                        title  year  vote_count  vote_average  \
# 0   19404  Dilwale Dulhania Le Jayenge  1995         661             9
# 1   27205                    Inception  2010       14075             8
# 2     155              The Dark Knight  2008       12269             8
# 3  157336                 Interstellar  2014       11187             8
# 4     550                   Fight Club  1999        9678             8
#
#    popularity                                             genres  \
# 0   34.457024                           [Comedy, Drama, Romance]
# 1   29.108149  [Action, Thriller, Science Fiction, Mystery, A...
# 2  123.167259                   [Drama, Action, Crime, Thriller]
# 3   32.213481                [Adventure, Drama, Science Fiction]
# 4   63.869599                                            [Drama]
#
#                                belongs_to_collection  \
# 0                                                NaN
# ...

# %%
## Merging Merge1(i.e. Qualified Data and Credits) with Keywords = MERGE 2

merge2 = merge1.merge(keywords,on='id')

# %%
merge2.head()
# Out:
#        id                        title  year  vote_count  vote_average  \
# 0   19404  Dilwale Dulhania Le Jayenge  1995         661             9
# 1   27205                    Inception  2010       14075             8
# 2     155              The Dark Knight  2008       12269             8
# 3  157336                 Interstellar  2014       11187             8
# 4     550                   Fight Club  1999        9678             8
#
#    popularity                                             genres  \
# 0   34.457024                           [Comedy, Drama, Romance]
# 1   29.108149  [Action, Thriller, Science Fiction, Mystery, A...
# 2  123.167259                   [Drama, Action, Crime, Thriller]
# 3   32.213481                [Adventure, Drama, Science Fiction]
# 4   63.869599                                            [Drama]
#
#                                belongs_to_collection  \
# 0                                                NaN
# ...

# %%
### Merging Merge2 (i.e Qualified Data , Credits, Keywords) with Links = MERGE 3 

merge3 = pd.merge(merge2, links.set_index('tmdbId'), left_on='id', right_index=True)

# %%
merge3.head()
# Out:
#        id                        title  year  vote_count  vote_average  \
# 0   19404  Dilwale Dulhania Le Jayenge  1995         661             9
# 1   27205                    Inception  2010       14075             8
# 2     155              The Dark Knight  2008       12269             8
# 3  157336                 Interstellar  2014       11187             8
# 4     550                   Fight Club  1999        9678             8
#
#    popularity                                             genres  \
# 0   34.457024                           [Comedy, Drama, Romance]
# 1   29.108149  [Action, Thriller, Science Fiction, Mystery, A...
# 2  123.167259                   [Drama, Action, Crime, Thriller]
# 3   32.213481                [Adventure, Drama, Science Fiction]
# 4   63.869599                                            [Drama]
#
#                                belongs_to_collection  \
# 0                                                NaN
# ...

# %%
### Merging Merge3 i.e (Qualified Data , Credits, Keywords, links) with ratings = MERGE4


merge4 = merge3.merge(rating,on='movieId')

# %%
merge4.head()

# %%
merge4.sort_values(by=['movieId'], ascending=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [233], in <cell line: 1>()
# ----> 1 merge4.sort_values(by=['movieId'], ascending=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
# ...
